# %% [markdown]
# ## Отработка данных сервостенда
#
# Чтобы обработать новый файл, нужно загрузить его в папку с помощью крестика слева во вкладке Notebooks & Files. Потом создать новую ячейку с кодом в конце этого ноутбука, записать в нее строчку
#
# clear_read_and_plot("имя файла.txt")
#
# Вместо "имя файла.txt" нужно написать имя файла с данными (в кавычках!). Чтобы запустить выполнение, можно нажать на синюю кнопку "Run notebook" справа сверху.

# %% [markdown]
# Если кнопка 'Run notebook' один раз была недавно нажата, то можно выполнить только одну ячейку с кодом для конкретного файла. Для этого нужно поставить курсор в ячейку и нажать одновременно Ctrl и Enter.

# %%
# %matplotlib inline
## Подключение библиотек
from my_input_modulo import clear_read_and_plot

# %% [markdown]
# ## Без светосборников

# %%
clear_read_and_plot("results_only_SiPM_final.txt")
# Out:
# Polynomial coefficients:  [ 9.63123447e-12 -5.06804833e-09  1.03991417e-06 -1.05067040e-04
#   4.07988497e-03  1.05013529e-01 -3.56970055e-02]
# Polynomial coefficients:  [ 3.31812935e-19 -2.89644290e-16  1.08032932e-13 -2.25174379e-11
#   2.88976708e-09 -2.38713906e-07  1.30225248e-05 -4.78595171e-04
#   1.05092492e-02  5.61027645e-02  4.78771199e-02]
# Polynomial coefficients:  [ 2.37217096e-26 -3.08077538e-23  1.79366532e-20 -6.17559508e-18
#   1.39686465e-15 -2.18114980e-13  2.40516380e-11 -1.88426595e-09
#   1.04159461e-07 -3.98994701e-06  1.03236808e-04 -1.77798145e-03
#   2.02145214e-02  2.84188951e-02  5.68362659e-02]
# Polynomial coefficients:  [-4.35214534e-34  6.11126185e-31 -3.75334726e-28  1.29155409e-25
#  -2.54644886e-23  2.01593451e-21  3.56426145e-19 -1.44152480e-16
#   2.48548076e-14 -2.77030561e-12  2.17377633e-10 -1.22992546e-08
#   5.01152271e-07 -1.44397739e-05  2.84718599e-04 -3.70222733e-03
#   3.10581036e-02  4.30492407e-03  6.27910759e-02]

# %% [markdown]
# ## Используем светосборники

# %%
clear_read_and_plot("results_light_collector_big_final.txt")
# Out:
# Polynomial coefficients:  [-1.05740868e-09  5.70446305e-07 -1.13956731e-04  1.02372196e-02
#  -3.98641839e-01  5.62164686e+00 -1.56271357e+01]
# Polynomial coefficients:  [-1.70251408e-16  1.53230357e-13 -5.83158963e-11  1.21982534e-08
#  -1.52641025e-06  1.16643099e-04 -5.34013898e-03  1.38301608e-01
#  -1.80327136e+00  9.19613234e+00 -8.09876881e+00]
# Polynomial coefficients:  [-2.02870924e-23  2.55781733e-20 -1.43502513e-17  4.72076537e-15
#  -1.01013822e-12  1.47447632e-10 -1.49805904e-08  1.06205665e-06
#  -5.19208571e-05  1.70416079e-03 -3.58658210e-02  4.48271885e-01
#  -2.90260612e+00  7.26975622e+00 -2.13323095e+00]
# Polynomial coefficients:  [-9.58190234e-32  1.48995471e-28 -1.00300937e-25  3.75049169e-23
#  -8.00710964e-21  7.17007875e-19  1.04264122e-16 -4.67981629e-14
#   8.20645180e-12 -9.00977768e-10  6.75906440e-08 -3.53834926e-06
#   1.28483018e-04 -3.15574238e-03  5.00567568e-02 -4.74147584e-01
#   2.33043445e+00 -4.37056956e+00  6.93245636e-01]

# %% [markdown]
# ## Новый файл
#
# Чтобы обработать новый файл, нужно загрузить его в папку с помощью крестика слева.
# Потом создать новую ячейку с кодом ниже, записать в нее строчку
#
# clear_read_and_plot("имя файла.txt")
#
# Вместо "имя файла.txt" нужно написать имя файла с данными.
# Чтобы запустить выполнение, можно нажать на кнопку Run notebook справа сверху.

# %%
clear_read_and_plot("Res_Acryl_lens_12.5_F8_no_contact.txt")
# Out:
# Polynomial coefficients:  [ 1.91494038e-11 -1.03739935e-08  2.54841431e-06 -3.54829869e-04
#   2.41547274e-02 -4.39760199e-01  1.40682642e+00]
# Polynomial coefficients:  [ 1.19691600e-17 -1.07053286e-14  4.03435719e-12 -8.31383889e-10
#   1.01646660e-07 -7.47264877e-06  3.18845430e-04 -7.23565721e-03
#   7.77740242e-02 -3.01115918e-01  1.90821726e-01]
# Polynomial coefficients:  [-1.37556308e-24  1.72582426e-21 -9.67032063e-19  3.19213743e-16
#  -6.89344675e-14  1.02232464e-11 -1.06291329e-09  7.76306914e-08
#  -3.92675380e-06  1.33278712e-04 -2.87886374e-03  3.65031253e-02
#  -2.36287811e-01  5.84967006e-01 -1.34813249e-01]
# Polynomial coefficients:  [-8.04248089e-33  1.25538507e-29 -8.47039779e-27  3.17136117e-24
#  -6.77585032e-22  6.07374229e-20  8.81403004e-18 -3.96135680e-15
#   6.94988217e-13 -7.62787282e-11  5.70940269e-09 -2.97001263e-07
#   1.06423123e-05 -2.55433750e-04  3.91772665e-03 -3.55329931e-02
#   1.66297853e-01 -2.93970257e-01  6.88307579e-02]

# %%
# можно обработать еще один файл
# clear_read_and_plot("Res_Acryl_lens_12.5_F8.txt")

# %%
clear_read_and_plot("Res_Acryl_lens_12.5_F8.txt")
# Out:
# Polynomial coefficients:  [-1.30940098e-11  7.48994822e-09 -1.76209069e-06  2.14836212e-04
#  -1.50537784e-02  6.29041633e-01  9.02962454e-01]
# Polynomial coefficients:  [ 1.36649670e-18 -1.17196768e-15  4.26199216e-13 -8.55077813e-11
#   1.02901448e-08 -7.51719699e-07  3.14392441e-05 -5.70082931e-04
#  -7.20243083e-03  6.22295149e-01  7.99021708e-01]
# Polynomial coefficients:  [ 1.27256942e-25 -1.62577452e-22  9.30995155e-20 -3.15412332e-17
#   7.02823542e-15 -1.08330259e-12  1.18278660e-10 -9.21218777e-09
#   5.08461194e-07 -1.94679708e-05  4.94975516e-04 -7.60091599e-03
#   5.00676723e-02  4.32050841e-01  8.97448443e-01]
