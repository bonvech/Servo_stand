# %% [markdown]
# ## Отработка данных сервостенда
#
# Чтобы обработать новый файл, нужно загрузить его в папку с помощью крестика слева во вкладке Notebooks & Files. Потом создать новую ячейку с кодом в конце этого ноутбука, записать в нее строчку
#
# clear_read_and_plot("имя файла.txt")
#
# Вместо "имя файла.txt" нужно написать имя файла с данными (в кавычках!). Чтобы запустить выполнение, можно нажать на синюю кнопку "Run notebook" справа сверху.

# %% [markdown]
# Если кнопка 'Run notebook' один раз была недавно нажата, то можно выполнить только одну ячейку с кодом для конкретного файла. Для этого нужно поставить курсор в ячейку и нажать одновременно Ctrl и Enter.

# %%
# %matplotlib inline
## Подключение библиотек
from my_input_modulo import clear_read_and_plot

# %% [markdown]
# ## Без светосборников

# %%
clear_read_and_plot("results_only_SiPM_final.txt")
# Out:
# Polynomial coefficients:  [ 9.63123447e-12 -5.06804833e-09  1.03991417e-06 -1.05067040e-04
#   4.07988497e-03  1.05013529e-01 -3.56970055e-02]
# Polynomial coefficients:  [ 3.31812935e-19 -2.89644290e-16  1.08032932e-13 -2.25174380e-11
#   2.88976708e-09 -2.38713906e-07  1.30225248e-05 -4.78595171e-04
#   1.05092492e-02  5.61027645e-02  4.78771199e-02]
# Polynomial coefficients:  [ 2.37217096e-26 -3.08077539e-23  1.79366533e-20 -6.17559510e-18
#   1.39686466e-15 -2.18114980e-13  2.40516380e-11 -1.88426595e-09
#   1.04159461e-07 -3.98994702e-06  1.03236809e-04 -1.77798146e-03
#   2.02145214e-02  2.84188950e-02  5.68362646e-02]
# Polynomial coefficients:  [-4.35214087e-34  6.11125595e-31 -3.75334389e-28  1.29155303e-25
#  -2.54644703e-23  2.01593367e-21  3.56425761e-19 -1.44152368e-16
#   2.48547909e-14 -2.77030398e-12  2.17377520e-10 -1.22992491e-08
#   5.01152081e-07 -1.44397694e-05  2.84718531e-04 -3.70222675e-03
#   3.10581017e-02  4.30492262e-03  6.27910824e-02]

# %% [markdown]
# ## Используем светосборники

# %%
clear_read_and_plot("results_light_collector_big_final.txt")
# Out:
# Polynomial coefficients:  [-1.05740868e-09  5.70446305e-07 -1.13956731e-04  1.02372196e-02
#  -3.98641839e-01  5.62164686e+00 -1.56271357e+01]
# Polynomial coefficients:  [-1.70251408e-16  1.53230357e-13 -5.83158963e-11  1.21982534e-08
#  -1.52641025e-06  1.16643099e-04 -5.34013898e-03  1.38301608e-01
#  -1.80327136e+00  9.19613233e+00 -8.09876881e+00]
# Polynomial coefficients:  [-2.02870925e-23  2.55781734e-20 -1.43502513e-17  4.72076539e-15
#  -1.01013822e-12  1.47447633e-10 -1.49805904e-08  1.06205665e-06
#  -5.19208574e-05  1.70416080e-03 -3.58658213e-02  4.48271888e-01
#  -2.90260615e+00  7.26975631e+00 -2.13323186e+00]
# Polynomial coefficients:  [-9.58188772e-32  1.48995277e-28 -1.00300826e-25  3.75048818e-23
#  -8.00710357e-21  7.17007585e-19  1.04263996e-16 -4.67981257e-14
#   8.20644626e-12 -9.00977224e-10  6.75906065e-08 -3.53834741e-06
#   1.28482954e-04 -3.15574086e-03  5.00567337e-02 -4.74147385e-01
#   2.33043375e+00 -4.37056971e+00  6.93242836e-01]

# %% [markdown]
# ## Новый файл
#
# Чтобы обработать новый файл, нужно загрузить его в папку с помощью крестика слева.
# Потом создать новую ячейку с кодом ниже, записать в нее строчку
#
# clear_read_and_plot("имя файла.txt")
#
# Вместо "имя файла.txt" нужно написать имя файла с данными.
# Чтобы запустить выполнение, можно нажать на кнопку Run notebook справа сверху.

# %% [markdown]
# Если кнопка 'Run notebook' один раз была недавно нажата, то можно выполнить только одну ячейку с кодом для конкретного файла. Для этого нужно поставить курсор в ячейку и нажать одновременно Ctrl и Enter.

# %%
clear_read_and_plot("Res_Acryl_lens_12.5_F8_no_contact.txt")
# Out:
# Polynomial coefficients:  [ 1.91494038e-11 -1.03739935e-08  2.54841431e-06 -3.54829869e-04
#   2.41547274e-02 -4.39760199e-01  1.40682642e+00]
# Polynomial coefficients:  [ 1.19691600e-17 -1.07053286e-14  4.03435719e-12 -8.31383889e-10
#   1.01646660e-07 -7.47264877e-06  3.18845430e-04 -7.23565721e-03
#   7.77740242e-02 -3.01115918e-01  1.90821726e-01]
# Polynomial coefficients:  [-1.37556310e-24  1.72582429e-21 -9.67032081e-19  3.19213749e-16
#  -6.89344690e-14  1.02232466e-11 -1.06291331e-09  7.76306936e-08
#  -3.92675392e-06  1.33278716e-04 -2.87886386e-03  3.65031269e-02
#  -2.36287824e-01  5.84967043e-01 -1.34813287e-01]
# Polynomial coefficients:  [-8.04249037e-33  1.25538634e-29 -8.47040513e-27  3.17136346e-24
#  -6.77585399e-22  6.07374231e-20  8.81404433e-18 -3.96136050e-15
#   6.94988762e-13 -7.62787828e-11  5.70940658e-09 -2.97001462e-07
#   1.06423196e-05 -2.55433932e-04  3.91772970e-03 -3.55330240e-02
#   1.66298017e-01 -2.93970616e-01  6.88304746e-02]

# %%
# можно обработать еще один файл

# %%
clear_read_and_plot("Res_Acryl_lens_12.5_F8.txt")
# Out:
# Polynomial coefficients:  [-1.30940098e-11  7.48994822e-09 -1.76209069e-06  2.14836212e-04
#  -1.50537784e-02  6.29041633e-01  9.02962454e-01]
# Polynomial coefficients:  [ 1.36649670e-18 -1.17196768e-15  4.26199216e-13 -8.55077813e-11
#   1.02901448e-08 -7.51719699e-07  3.14392441e-05 -5.70082931e-04
#  -7.20243083e-03  6.22295149e-01  7.99021708e-01]
# Polynomial coefficients:  [ 1.27256944e-25 -1.62577455e-22  9.30995173e-20 -3.15412338e-17
#   7.02823557e-15 -1.08330261e-12  1.18278663e-10 -9.21218798e-09
#   5.08461206e-07 -1.94679713e-05  4.94975527e-04 -7.60091616e-03
#   5.00676736e-02  4.32050838e-01  8.97448458e-01]
# Polynomial coefficients:  [-4.86188386e-34  1.01041401e-30 -8.23776528e-28  3.56305200e-25
#  -8.69436225e-23  9.68925828e-21  8.49252282e-19 -5.36140472e-16
#   1.05800971e-13 -1.28482765e-11  1.07094687e-09 -6.31738156e-08
#   2.64160567e-06 -7.69748683e-05  1.50546477e-03 -1.83069247e-02
#   1.09533919e-01  3.03990650e-01  9.25652279e-01]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=29d69147-c483-44f1-9c27-9c61510e33f7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
